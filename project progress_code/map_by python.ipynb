# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd

# %%
import os
os.getcwd()
os.chdir("C:/Users/lenovo/Desktop/ke")

# %%
data = pd.read_csv('./map.txt', sep='\t')
data
# Out:
#                 Country/Region        Lat       Long  confirmed  death
# 0                  Afghanistan  33.000000  65.000000        521     15
# 1                      Albania  41.153300  20.168300        416     23
# 2                      Algeria  28.033900   1.659600       1761    256
# 3                      Andorra  42.506300   1.521800        601     26
# 4                       Angola -11.202700  17.873900         19      2
# ..                         ...        ...        ...        ...    ...
# 259  Saint Pierre and Miquelon  46.885200 -56.315900          1      0
# 260                South Sudan   6.877000  31.307000          4      0
# 261             Western Sahara  24.215500 -12.885800          4      0
# 262      Sao Tome and Principe   0.186360   6.613081          4      0
# 263                      Yemen  15.552727  48.516388          1      0
#
# [264 rows x 5 columns]

# %%
world_map = folium.Map ( location = [10,20], zoom_start = 2.3, tiles = 'Stamen Toner' )

# %%
for lat, long, confirmed, death, name in zip ( data['Lat'], data['Long'], data['confirmed'], data['death'], data['Country/Region'] ):
    folium.CircleMarker ([lat, long],
                        radius = 10,
                        popup = ('<strong>Country/Region</strong>: ' + str(name).capitalize() + '<br>' 
                                + '<strong>Confirmed</strong>: ' + str(confirmed) + '<br>'
                                + '<strong>Death</strong>: ' + str(death) + '<br>'),
                        color = 'red',
                        fill_color = 'red',
                        fill_opacity = 0.7 ).add_to(world_map)

# %%
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
